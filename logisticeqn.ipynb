# %% [markdown]
# <a href="https://colab.research.google.com/github/nwkrix/pythonbasics/blob/master/logisticeqn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def logisic(x,r):
    return r*x*(1-x)
N = int(1e2)
import numpy as np
import matplotlib.pyplot as plt
t = np.linspace(0,1,N)
x = np.zeros(N)
x[0] = 0.01
for k in range(0,N-1):
    x[k+1] = model(x[k],3.6)
plt.plot(t,x)

# %%
import numpy as np
import matplotlib.pyplot as plt
def logistic(x0,r,tEnd,N): #function definition
    x = np.zeros(N)
    x[0] = x0
    t = np.linspace(0,tEnd,N)
    for k in range(0,N-1):
        x[k+1] = r*x[k]*(1-x[k])
    plt.plot(t,x) #the function 'logistic([],[],[],[])' returns a plot of the solution
logistic(0.01,3.6,1,100)
